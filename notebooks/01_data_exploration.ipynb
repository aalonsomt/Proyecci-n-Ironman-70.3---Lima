# %% [markdown]
# <a href="https://colab.research.google.com/github/aalonsomt/Proyecci-n-Ironman-70.3---Lima/blob/main/notebooks/01_data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("IRONMAN 70.3 Lima Analytics")
# Out:
# IRONMAN 70.3 Lima Analytics
